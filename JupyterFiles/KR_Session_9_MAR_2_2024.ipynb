# %%
import os

# %%
cwd=os.getcwd()

# %%
cwd
# Out:
# '/Users/admin/Movies'

# %%
os.chdir("/Users/admin/Movies/test/")

# %%
os.getcwd()
# Out:
# '/Users/admin/Movies/test'

# %%
os.mkdir("dir1")

# %%
os.makedirs("python/django/files")

# %%
#os.rmdir("dir1") #empty

# %%
os.removedirs("python/django/files") #empty

# %%
os.remove("dir1/test_module.py")

# %%
os.rename("dir1","newname") #file and dir

# %%
data=os.listdir("/Users/admin/Movies/")

# %%
data
# Out:
# ['untitled folder',
#  'KR_Session_6_FEB_11_2024.ipynb',
#  'KR_Session_8_April_30_2023.ipynb',
#  'SL_session_9_FEB_18_2023.ipynb',
#  'KR_13_APRIL_2023.ipynb',
#  'KR_5_FEB_19_2023.ipynb',
#  'KR_10_JAN_6_2024.ipynb',
#  'localrepo',
#  'Untitled10.ipynb',
#  'GL_Week_4_28_jan_2023.ipynb',
#  'Untitled7.ipynb',
#  'kr-4_jan_2023.ipynb',
#  'SL_Session_6_MAR_19_2023.ipynb',
#  'Day-2.zip',
#  'SL_session_2_oct_2_2022.ipynb',
#  'kr_10_Dec_17.ipynb',
#  'KR_13_NOV_25_2023.ipynb',
#  'List_Tuple_Dict_Set.ipynb',
#  'KR_Session_7_April_29.ipynb',
#  'SQL_Engine.ipynb',
#  'india.csv',
#  'KR_Session_4_April_15.ipynb',
#  'Client.spec',
#  'GL_week_8_FEB_25_2023.ipynb',
#  'SL_Session_4_sept_15_2022.ipynb',
#  'session_files_01132024.zip',
#  'SL_Session-1-April-22-2023.ipynb',
#  'out.txt',
#  'SL_session_5_sept_16_2022.ipynb',
#  'KR_3_Session_FEB_11_2023.ipynb',
#  'salary_data.csv',
#  'Online Car Rental Platform.ipynb',
#  'Untitled12.ipynb',
#  'kr-8-jan22-2023.ipynb',
#  'KR_session_12_Aug_12_2023.ipynb',
#  'Untitled5.ipynb',
#  'testdir1',
#  'Server.py',
#  'SL_Session_2_April_23_2023.ipynb',
#  'KR_Session_15_JAN_28_2024.ipynb',
#  'pakage',
#  'mypack1',
#  'temp.csv',
#  'SL_Session_2_Nov_27_2022.ipynb.zip',
#  'kr_6_Nov_27_2022.ipynb',
#  'SL_Session_1_Sept_12_2022.ipynb',
#  'Untitled1.ipynb',
#  'KR_3_Aug_26_2023.ipynb',
#  'KR_5_DEÇ_16_2023.ipynb',
#  'GL_test3',
#  'db_connection file.ipynb',
#  'SL_Session_7_FEB_11_2023.ipynb',
#  'Untitled16.ipynb',
#  'KR_session_23_JAN_7_2024.ipynb',
#  'kr_11_Nov_13.ipynb',
#  '.DS_Store',
#  'KR_11_Nov_18_2023.ipynb',
#  'KR_14_OCT_2023.ipynb',
#  'KR_17_july_29_2023.ipynb',
#  'GL-2',
#  'KR_19_Nov_5_2023.ipynb',
#  'SL_session_3_sept_14_2022.ipynb',
#  'Day-4.zip',
#  'kr_session_3.ipynb',
#  'KR_12_Dec_22.ipynb',
#  'lr_model.pkl',
#  'KR-5-April-22.ipynb',
#  'Untitled32.ipynb',
#  'SL_Session_3_oct_8_2022.ipynb',
#  'KR-15-April-2023.ipynb',
#  'SL_Session_8_May_14_2023.ipynb',
#  'KR_10_Jan_29_2023.ipynb',
#  'KR_1_DEC_2_2023.ipynb',
#  'KR_2_May_28_2023.ipynb',
#  'KR_14_july_16_2023.ipynb',
#  'KR-17-April-22.ipynb',
#  'test',
#  'kr_11_Dec_24_2022.ipynb',
#  'kr-5-1-3.ipynb',
#  'KR_16_Jun_2023.ipynb',
#  'Untitled30.ipynb',
#  'SL_Session_4_oct_30_2022.ipynb',
#  'KR_Network_4_July_2023.ipynb',
#  'SL_Session-1-April-22-2023.ipynb.zip',
#  's3.txt',
#  'Untitled29.ipynb',
#  'KR-8-july_23_2023.ipynb',
#  'testrepo',
#  'KR_14_FEB_19_2023.ipynb',
#  'dist',
#  'GL_week_2_8_july_2023.ipynb',
#  'kR_9_june_25_2023.ipynb',
#  '.localized',
#  'Untitled3.ipynb',
#  'SL_Session_4_Aug_29_2022.ipynb',
#  'Untitled14.ipynb',
#  'mypackage',
#  'test_module.py',
#  'KR_12_MAR_26_2023.ipynb',
#  'Session_files_01202024',
#  'KR_13_July_15_2023.ipynb',
#  'Untitled.ipynb',
#  'KR_9_Nov_4_2023.ipynb',
#  'KR_1_Aug_19_2023.ipynb',
#  'kr_5_Aug_28.ipynb',
#  'SL_Session_1_May_27_2023.ipynb.zip',
#  'SL_Session_7_FEB_11_2023.ipynb.zip',
#  'session_2_kr.ipynb',
#  'KR_Session_19_FEB_11_2024.ipynb',
#  'KR_Session_8_Sep23_2023.ipynb',
#  'demopackage',
#  'SL_Session_DB_Connection.ipynb',
#  'SL_Session_4_Jun_2023.ipynb',
#  'KR_Session_9_jan_28_2023.ipynb',
#  'SL_Session_8_FEB_12_2023.ipynb',
#  'testdemomodule.py',
#  'KR_18_Jun_11_2023.ipynb',
#  'KR-4-Jun-2023.ipynb',
#  'SL_Session_1_May_27_2023.ipynb',
#  'SL_Session_9_June_24_2023.ipynb',
#  'KR_15_Aug_26_2023.ipynb',
#  'Untitled4.ipynb',
#  'Session_files_01212024',
#  'Untitled13.ipynb',
#  'Untitled6.ipynb',
#  'KR_13_May_27_2023.ipynb',
#  'KR_session_7_10_sep_2023.ipynb',
#  'Untitled11.ipynb',
#  'Client.py',
#  'SL_Session_3_Jun_2023.ipynb',
#  'KR_6_Jun_10_2023.ipynb',
#  'marketing_project.ipynb',
#  'SL_Session_4_jan_29_2023.ipynb',
#  'SL_Session_6_Feb_5_2023.ipynb',
#  'KR_12_OCT_8_2023.ipynb',
#  'KR_8_MAR_5_2023.ipynb',
#  'KR_6_july_16_2023.ipynb',
#  'GL_Week_6_FEB_11_2023.ipynb',
#  'KR_14_May_28_2023.ipynb',
#  'KR_17_Sept_3_2023.ipynb',
#  'kr-7-jan-21-2023.ipynb',
#  'kr_15_Nov_27_2022.ipynb',
#  'KR_6_Sept_3_2023.ipynb',
#  'SL_Session_4_oct_9_2022.ipynb',
#  'KR_Session_14_JAN_27_2024.ipynb',
#  'KR_3_DEC_9_2023.ipynb',
#  'Untitled31.ipynb',
#  'KR_Session_5_july_15_2023.ipynb',
#  'KR_17_Jun_10_2023.ipynb',
#  'Untitled15.ipynb',
#  'KR_Session_7_FEB_24_2024.ipynb',
#  'SL_session_3_sept_14_2022 2.ipynb',
#  'SL_Session_2_Nov_27_2022.ipynb',
#  'SL_Session_8_Sept_11_2022.ipynb',
#  'SL_Session_1_Jan_21_2023.ipynb',
#  'KR_12_JAN_14_2024.ipynb',
#  'SL_Session_4_Dec_4_2022.ipynb',
#  'Untitled2.ipynb',
#  'KR_Session_11.ipynb',
#  'Day-5 11.04.49 PM',
#  'GL_test',
#  'Session_files_01272024.zip',
#  'Session_files_01272024',
#  'KR_14_OCT_14_2023.ipynb',
#  'Untitled28.ipynb',
#  'SL_Session_3_Aug_27_2022.ipynb.zip',
#  'KR_4_OCT_14_2023.ipynb',
#  'SL_Session_6_Sep_3_2022.ipynb',
#  'SL_Session_6_sept_19_2022.ipynb',
#  'SL_Session_5_Jun_10_2023.ipynb',
#  '__pycache__',
#  'tempdata.xlsx',
#  'SL_Session_2_May_28_2023.ipynb',
#  'kr_13.ipynb',
#  'KR_session_11_JAN132024.ipynb',
#  'Untitled17.ipynb',
#  'KR_Session_9_sep24_2023.ipynb',
#  'data.xlsx',
#  'module1.py',
#  'Kr_4_Nov_13.ipynb',
#  'KR-7_Nov_3_2022.ipynb',
#  'KR_6_OCT_21_2023.ipynb',
#  'train2.csv',
#  'TV',
#  'SL_Session_3_April_29_2023.ipynb',
#  'KR-18-APRIL-23-2023.ipynb',
#  'data.csv',
#  'testpackage',
#  'KR_16_03022024.ipynb',
#  'kr_session_9_sept_2022.ipynb',
#  'KR_3_July_8_2023.ipynb',
#  'SL_Session_4_sept_15_2022.ipynb.zip',
#  'SL_Session_4_MAR_12_2023.ipynb',
#  'KR_4_DEC_10_2023.ipynb',
#  'kr-9-Dec_11_2022.ipynb',
#  'demo1.py',
#  'KR_12_FEB_12_2023.ipynb',
#  'Session_files_01142024.zip',
#  'KR_10_July_30_2023.ipynb',
#  'Intro To stats.pdf',
#  'SL_Session_sept_20_2022.ipynb',
#  'KR_16_Aug_27_2023.ipynb',
#  'KR_16_OCT_22_2023.ipynb',
#  'KR_3_April_9_2023.ipynb',
#  'inida.csv',
#  'KR_Session_2_JAN_28_2024.ipynb',
#  'Session_files_03022024',
#  'Untitled26.ipynb',
#  'Session_files_01282024',
#  'Session_files_01142024',
#  'SL_Session_8_MAR_26_2023.ipynb',
#  'log.txt',
#  'Kr_1_Nov_6.ipynb',
#  'SL_Session_DB_Connection.ipynb.zip',
#  'kr_5_Nov_26.ipynb',
#  'Untitled24.ipynb',
#  'KR_Session_8_DEC_30_2023.ipynb',
#  'Untitled19.ipynb',
#  'kr1-3-session-4.ipynb',
#  'sqlconf.config',
#  'KR_Session_13_Aug_13_2023.ipynb',
#  'complain types using NLP (project task).ipynb',
#  'kr_14_Aug_27_2022.ipynb',
#  'SL_Session_3_MAR_10_2023.ipynb',
#  'SL_Session_6_sept_19_2022.ipynb.zip',
#  'KR_5_jun_2023.ipynb',
#  'session_files_01132024',
#  'SL_Session_2_MAR_5_2023.ipynb',
#  'KR_10_NOV_5_2023.ipynb',
#  'Day-8',
#  'kr-2-4-7pm.ipynb',
#  'SL_Session_1_Jan_21_2023.ipynb.zip',
#  'kr_session_6_jan_15_2023.ipynb',
#  'KR_18_DEC_16_2023.ipynb',
#  'weather.csv',
#  'SL_Session_4_Aug_29_2022.ipynb.zip',
#  'KR_5_Sept_2_2023.ipynb',
#  'KR_9_july_29_2023.ipynb',
#  'Seven_day_forcast.csv',
#  'Untitled20.ipynb',
#  'KR_16_july_23_2023.ipynb',
#  'KR_9_May_6_2023.ipynb',
#  'kr-5-jan-2023.ipynb',
#  'SL_Session-2_Aug_21_2022.ipynb',
#  'Session_files_03022024.zip',
#  'SL_session_3_sept_14_2022.ipynb.zip',
#  'SL_Session_3_Jan_28_2023.ipynb',
#  'file.xlsx',
#  'kr-12.ipynb',
#  'Untitled8.ipynb',
#  'KR_14_NOV_26_2023.ipynb',
#  'GL_week4_Aug_28_2022.ipynb',
#  'KR_11_July_2_2023.ipynb',
#  'user.db',
#  'Untitled22.ipynb',
#  'SL_session_5_sept_16_2022.ipynb.zip',
#  'KR_14_Aug_20_2023.ipynb',
#  'GL_Session_3_july_24_2022.ipynb',
#  'SL_Session_6_Jun_11_2023.ipynb',
#  'SL_Session_2_Aug_27_2022.ipynb',
#  'KR_6_DEC_17_2023.ipynb',
#  'KR_Session_4_03_FEB_2024.ipynb',
#  'KR-16-April-15-2023.ipynb',
#  'GLD1',
#  'user.csv',
#  'newtrain.csv',
#  'SL_Session_2_sept_13_2022.ipynb',
#  'KR_12_july_8_2023.ipynb',
#  'GL_test1',
#  'Session_files_01212024.zip',
#  'SL_Session_2_sept_13_2022.ipynb.zip',
#  'train.csv',
#  '.ipynb_checkpoints',
#  'KR_5_OCT_2023.ipynb',
#  'Untitled18.ipynb',
#  'Untitled25.ipynb',
#  'KR_15_DEC_2_2023.ipynb',
#  'KR_Session_5_FEB_10_2024.ipynb',
#  'SL_Session_5_Dec_10.ipynb',
#  'session-kr-14.ipynb',
#  'KR_7_28_OCT_2023.ipynb',
#  'kr_8_Nov_5.ipynb',
#  'KR_2_OCT_7_2023.ipynb',
#  'KR-6-April-23-2023.ipynb',
#  'KR_2_July_2_2023.ipynb',
#  'indian_state.csv',
#  'dir1',
#  'kr-8-Dec-4-2022.ipynb',
#  'Day-9-2.zip',
#  'SL_Session_1_Sept_12_2022.ipynb.zip',
#  'KR_11_MAR_25_2023.ipynb',
#  'KR_13_FEB_18_2023.ipynb',
#  'GL_Session_2_july_17_2022.ipynb',
#  'build',
#  'Sl_Session_8_Nov_13.ipynb',
#  'SL_Session_5_MAR_18_2023.ipynb',
#  'testkey.pem',
#  'SL_Session_6_Nov_6_2022.ipynb',
#  'Session_files_01282024.zip',
#  'GL_Session_3_july_15.ipynb',
#  'KR_11_OCT_7_2023.ipynb',
#  'KR_11_Aug_5_2023.ipynb',
#  'error.txt',
#  'KR_4_Aug_27_2023.ipynb',
#  'Untitled27.ipynb',
#  'KR_3_OCT_8_2023.ipynb',
#  'KR_2_Aug_20_2023.ipynb',
#  'KR_16_DEC_9_2023.ipynb',
#  'Day-9-1.zip',
#  'SL_Session_3_29_oct_2022.ipynb',
#  'KR_12_May_14_2023.ipynb',
#  'KR_10_30_Sep_2023.ipynb',
#  'anydesk',
#  'KR_Session_21_Jan_2024.ipynb',
#  'mypack',
#  'Untitled23.ipynb',
#  'KR_12_NOV_19_2023.ipynb',
#  'GL_Week_3_Aug_20.ipynb',
#  'SL_Session_7_MAR_25_2023.ipynb',
#  'SL_Session_9_APRIL_1_2023.ipynb',
#  'SL_Session_2_May_28_2023.ipynb.zip',
#  'Untitled9.ipynb',
#  'KR_15_June_2023.ipynb',
#  'List_Tuple_Dict_Set.ipynb.zip',
#  'KR_4_FEB_12_2023.ipynb',
#  'KR_Session_3_03_FEB_2024.ipynb',
#  'output.txt',
#  'addusermodule.py',
#  'SL_Session-2_Aug_21_2022.ipynb.zip',
#  'web_scraping.ipynb',
#  'Sl_Session_5_Nov_5_2022.ipynb',
#  'kr_13_26_Nov.ipynb',
#  'Session_files_01202024.zip',
#  'reg.pkl',
#  'KR_14_FEb_25_2023.ipynb',
#  'demokey.pem',
#  'examplekr.py',
#  'kr-16-4-6.ipynb',
#  'filename.py',
#  'abc.py',
#  'KR_8_OCT_29_2023.ipynb',
#  'KR_11_May_13_2023.ipynb',
#  'KR-6-1-3.ipynb',
#  'Untitled21.ipynb']

# %%
os.listdir(".")
# Out:
# ['.DS_Store', 'abc.txt', 'newname', '.ipynb_checkpoints', 'dir1', '.git']

# %%
data=os.walk(".")

for cwd,dirs,file in data:
    print("CWD :",cwd)
    print("Directorys :",dirs)
    print("Files :",file)
# Out:
# '\nfor cwd,dirs,file in data:\n    print("CWD :",cwd)\n    print("Directorys :",dirs)\n    print("Files :",file)\n'

# %%
list(data)
# Out:
# [('.',
#   ['newname', '.ipynb_checkpoints', 'dir1', '.git'],
#   ['.DS_Store', 'abc.txt']),
#  ('./newname', ['test'], ['file1.txt', 'data.csv']),
#  ('./newname/test', [], []),
#  ('./.ipynb_checkpoints',
#   [],
#   ['GL_week_5_FEB_4_2023-checkpoint.ipynb',
#    'KR_Session_1_FEB_5_2023-checkpoint.ipynb',
#    'Untitled-checkpoint.ipynb',
#    'KR_11_FEB_5_2023-checkpoint.ipynb']),
#  ('./dir1', [], ['dev.json']),
#  ('./.git',
#   ['objects', 'info', 'logs', 'hooks', 'refs'],
#   ['config', 'HEAD', 'description', 'index', 'COMMIT_EDITMSG']),
#  ('./.git/objects', ['5f', 'b2', 'pack', '89', 'info'], []),
#  ('./.git/objects/5f', [], ['4f7050d0117d4d0f2ce3b1acec9136150f8094']),
#  ('./.git/objects/b2', [], ['bb95f2ce50f7a8f89499822068847dd410ad00']),
#  ('./.git/objects/pack', [], []),
#  ('./.git/objects/89', [], ['918a13a2553ea0721915f13c020b27e43c5ae6']),
#  ('./.git/objects/info', [], []),
#  ('./.git/info', [], ['exclude']),
#  ('./.git/logs', ['refs'], ['HEAD']),
#  ('./.git/logs/refs', ['heads'], []),
#  ('./.git/logs/refs/heads', [], ['master']),
#  ('./.git/hooks',
#   [],
#   ['commit-msg.sample',
#    'pre-rebase.sample',
#    'pre-commit.sample',
#    'applypatch-msg.sample',
#    'fsmonitor-watchman.sample',
#    'pre-receive.sample',
#    'prepare-commit-msg.sample',
#    'post-update.sample',
#    'pre-applypatch.sample',
#    'pre-push.sample',
#    'update.sample']),
#  ('./.git/refs', ['heads', 'tags'], []),
#  ('./.git/refs/heads', [], ['master']),
#  ('./.git/refs/tags', [], [])]

# %%
x=os.stat("abc.txt")

# %%
x
# Out:
# os.stat_result(st_mode=33188, st_ino=43887267, st_dev=16777220, st_nlink=1, st_uid=501, st_gid=20, st_size=1446, st_atime=1709366566, st_mtime=1709366564, st_ctime=1709366564)

# %%
x.st_size
# Out:
# 1446

# %%
x.st_ctime
# Out:
# 1709366564.0527122

# %%
import time

# %%
time.ctime(x.st_ctime)
# Out:
# 'Sat Mar  2 13:32:44 2024'

# %%
oct(x.st_mode)
# Out:
# '0o100644'

# %%
oct(x.st_mode)[-3:]
# Out:
# '644'

# %%
import stat

# %%
os.chmod("abc.txt",stat.S_IRWXU |stat.S_IRGRP |stat.S_IWGRP |stat.S_IROTH)

# %%
os.chmod("abc.txt",0o644)

# %%
import shutil

# %%
shutil.copy("newname/data.csv","dir1/")
# Out:
# 'dir1/data.csv'

# %%
shutil.copyfile("newname/data.csv","dir1/data.csv")
# Out:
# 'dir1/data.csv'

# %%
shutil.copy2("newname/data.csv","dir1/")

# %%
shutil.copytree(".","/Users/admin/Desktop/abc")
# Out:
# '/Users/admin/Desktop/abc'

# %%
shutil.rmtree("newname")

# %%
shutil.move("dir1/dev.json","dir2")
# Out:
# 'dir2/dev.json'

# %%
shutil.get_archive_formats()
# Out:
# [('bztar', "bzip2'ed tar-file"),
#  ('gztar', "gzip'ed tar-file"),
#  ('tar', 'uncompressed tar file'),
#  ('xztar', "xz'ed tar-file"),
#  ('zip', 'ZIP file')]

# %%
shutil.make_archive("/Users/admin/Desktop/logs","zip",".")
# Out:
# '/Users/admin/Desktop/logs.zip'

# %%
shutil.unpack_archive('/Users/admin/Desktop/logs.zip',"/Users/admin/Desktop/logs")

# %%
count+1

# %%
import os.path

# %%
p="/Users/admin/Desktop/logs.zip"

# %%
os.path.basename(p)
# Out:
# 'logs.zip'

# %%
os.path.dirname(p)
# Out:
# '/Users/admin/Desktop'

# %%
import os

# %%
os.path.getsize("/Users/admin/Desktop/log.txt") #bytes
# Out:
# 1709

# %%
os.path.getctime("/Users/admin/Desktop/log.txt")
# Out:
# 1700987003.647071

# %%
os.path.getmtime("/Users/admin/Desktop/log.txt")
# Out:
# 1700987000.4925838

# %%
os.path.getatime("/Users/admin/Desktop/log.txt")
# Out:
# 1701493925.3107567

# %%
data=os.listdir("/Users/admin/Documents/data visualization/")

# %%
for file in data:
    size=os.path.getsize(os.path.join("/Users/admin/Documents/data visualization/",file))
    print(file,"\t",size)
# Out:
# K-means.ipynb 	 51597
# Untitled1.ipynb 	 110815
# Untitled.ipynb 	 121009
# Pie chart.ipynb 	 20410
# KNN.ipynb 	 20690
# matplotlib_bar.ipynb 	 38795
# Untitled2.ipynb 	 54077
# LGR.ipynb 	 25572
# Seaborn lib.ipynb 	 243818
# Histogram.ipynb 	 133937
# matplotlib_scatterplot.ipynb 	 133757
# .ipynb_checkpoints 	 352
# IPL DA.ipynb 	 207087

# %%
file=input("enter name :")

#if os.path.exists(file):
#if os.path.isfile(file):
#if os.path.isdir(file):
#if os.path.ismount(file)
#if os.path.islink(file)
# Out:
# enter name :abc
