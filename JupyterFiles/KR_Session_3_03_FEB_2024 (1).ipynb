# %%
#data types :
 
1 : int , float , bool , str , complex :


int : [0-9] => x=56789
float : => 23.4 , 56.789 , 
bool : 
    True : 1
    False : 0
        
        
str :
    
' ' : char, word
" " : line

''' ''' : M. line
""" """


complex :
    
    <real>+<imag>j

# %%
x="you can't do this"
type(x)
# Out:
# str

# %%
st='''line1
line2
line3'''

# %%
print(st)
# Out:
# line1
# line2
# line3

# %%
x=4+5j
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 4.0

# %%
x.imag
# Out:
# 5.0

# %%
x
# Out:
# (4+5j)

# %%
x="192.168.0.1"
type(x)
# Out:
# str

# %%
password="redhat@123"

# %%
#operators :


1 : + , - , * , / , % , // , **

# %%
x=23
y=45
#x+y
#x-y
#x*y

#13%2

#13/2 : float
#12/2

#12//2 : int
#13//2 

4**3
# Out:
# 64

# %%
2 : == , != , < ,> ,<=,>=
    
    
= vs ==

x=23
y=45

x==y


< vs <=
# Out:
# False

# %%
x=23
y=45

x=y

# %%
18<=18
# Out:
# True

# %%
#and , or, not 


condition1 and condition2

T            +        T     : T
T            +        F     : F
F            +        T     : F
F            +        F     : F
    
    
condition1 or condition2

T            +        T     : T
T            +        F     : T
F            +        T     : T
F            +        F     : F

# %%
(4>5 or 6==6)
# Out:
# True

# %%
not 40>5
# Out:
# False

# %%
# membership : in , not in


users=["amit","sam","root","rohan","mike"]

#"root" in users
"Root" not in users
# Out:
# True

# %%
x="welcome"
y="welcome"

id(x),id(y)
# Out:
# (140387343645680, 140387343645680)

# %%
int : 0-256
float : will not work
bool : True,False
str : 
complex : will not work

# %%
a=0.1
b=0.1
id(a),id(b)
# Out:
# (140387345086320, 140387345949296)

# %%
#identity : is , is not



x=23
y=23


#x==y

x is y
# Out:
# True

# %%
x=789
y=789


#x==y
x is y
# Out:
# False

# %%
# x=89
#def adduser():
#class Student:

# %%
#1 : [a-zA-Z0-9] [_]
#2 : char , [_ ]
#3 : space
#4 : keywords :

# %%
student_name="Amit"
