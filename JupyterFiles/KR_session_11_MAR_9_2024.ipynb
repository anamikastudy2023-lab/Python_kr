# %%
#Exception handling :

# %%
print("start")
x=2
result=10/x
print(result)
print("end")
# Out:
# start
# 5.0
# end

# %%
print("start")
x=
result=10/x
print(result)
print("end")
# Out:
# start
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-9cfd568017e6> in <module>
#       1 print("start")
#       2 x=0
# ----> 3 result=10/x
#       4 print(result)
#       5 print("end")
#
# ZeroDivisionError: division by zero

# %%
try
except
finally
else

# %%
print("start")
x=0
try:
    result=10/x
    print(result)
except ZeroDivisionError :
    print("can't div by zero")
print("end")
# Out:
# start
# can't div by zero
# end
# 11

# %%
print("start")
x=2
list1=[2,3,4,5]
try:
    result=10/x. ----
    try:
        print(list1[4])
    except IndexError as ex:-----
        print(ex)
    print(result)
except ZeroDivisionError :
    print("can't div by zero")
print("end")
# Out:
# start
# list index out of range
# 5.0
# end

# %%
print("start")
x=2
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[4])
    print(result)
except ZeroDivisionError :
    print("can't div by zero")
except IndexError as ex:
        print(ex)
print("end")
# Out:
# start
# list index out of range
# end

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[4])
    print(result)
except (ZeroDivisionError,IndexError )as ex:
    print(ex)

print("end")
# Out:
# start
# division by zero
# end

# %%
print("start")
x=2
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[4])
    print(result)
except Exception as ex:
    print(ex)

print("end")
# Out:
# start
# list index out of range
# end

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[4])
    print(result)
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex:
    print(ex)
    

print("end")
# Out:
# start
# division by zero
# end

# %%
import traceback,sys

print("start")
x=2
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[4])
    print(result)
except Exception as ex:
    traceback.print_exc(file=sys.stdout)
    

print("end")
# Out:
# start
# Traceback (most recent call last):
#   File "<ipython-input-25-82982c10a8ad>", line 8, in <module>
#     print(list1[4])
# IndexError: list index out of range
# end

# %%
try:
    con=connect()
    sql1
    sql2
    sql3

except SQLException as ex:
    print(ex)
finally:
    con.close()

# %%
print("start")
x=0
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[2])
    print(result)
except Exception as ex:
    print(ex)
finally:
    print("finally block")
print("end")
# Out:
# start
# division by zero
# finally block
# end

# %%
print("start")
x=2
list1=[2,3,4,5]
try:
    result=10/x
    print(list1[2])
    print(result)
except Exception as ex:
    print(ex)
else:
    print("else block")
finally:
    print("finally block")
print("end")
# Out:
# start
# 4
# 5.0
# else block
# finally block
# end

# %%
def checkAge(age):
    if type(age)!=int:
        raise TypeError(f"type of age must be int not {type(age)}")
    if age>18:
        print("valid")
    else:
        print("not valid")

# %%
try:
    checkAge('23')
except TypeError as ex:
    print(ex)
# Out:
# type of age must be int not <class 'str'>

# %%
 checkAge('23')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-ea1e83c3b06f> in <module>
# ----> 1 checkAge('23')
#
# <ipython-input-33-9fe646c5b13c> in checkAge(age)
#       1 def checkAge(age):
#       2     if type(age)!=int:
# ----> 3         raise TypeError(f"type of age must be int not {type(age)}")
#       4     if age>18:
#       5         print("valid")
#
# TypeError: type of age must be int not <class 'str'>

# %%
class InvalidAgeError(Exception):
    ''' doc string'''
        pass

# %%
def checkAge(age):
    if type(age)!=int:
        raise InvalidAgeError(f"type of age must be int not {type(age)}")
    if age>18:
        print("valid")
    else:
        print("not valid")

# %%
some notes on Exception Handling :

# %%
 try:
    checkAge('23')
except Exception as ex:
    print(ex)
# Out:
# type of age must be int not <class 'str'>

# %%
Python initially has some exceptions, but if we import any additional libraries, then they may have their own defined exceptions. 
We may have additional types of exceptions goes up.

# %%
Example	Topic	Key Concepts
Ex 1	Normal execution	No error, all lines run sequentially
Ex 2	Unhandled exception	ZeroDivisionError crashes the program
Ex 3	Basic try-except	Catches ZeroDivisionError, program continues
Ex 4	Nested try-except	Inner & outer try blocks handle different errors
Ex 5	Multiple except blocks	Different except for ZeroDivisionError vs IndexError
Ex 6	Grouped exceptions	except (Error1, Error2) as ex: in one block
Ex 7	Generic Exception	Catch-all handler using base Exception class
Ex 8	Specific + Generic	Specific exceptions before generic Exception
Ex 9	traceback module	traceback.print_exc() for detailed stack trace
Ex 10	finally (DB pattern)	Resource cleanup — con.close() always runs
Ex 11	try-except-finally	finally block always executes
Ex 12	try-except-else-finally	Complete structure — else runs only if NO error
Ex 13	raise keyword	Manually raising exceptions for validation
Ex 14	Catching raised errors	try-except catches the raised exception
Ex 15	Unhandled raise	Without try-except, raised exception crashes
Ex 16	Custom Exception class	class InvalidAgeError(Exception)
Ex 17	Using custom exception	raise InvalidAgeError(...) in functions
Ex 18	Catching custom exception	Custom exceptions caught by except Exception

# %%
Cell	Comment Notes Added
Header	Overview of Exception Handling, common exception types
Ex 1-2	Normal execution vs unhandled ZeroDivisionError crash
Ex 3	Basic try-except with ZeroDivisionError
Ex 4	Nested try-except blocks
Ex 5	Multiple except blocks for different exceptions
Ex 6	Grouping exceptions: except (Error1, Error2) as ex:
Ex 7	Generic Exception catch-all
Ex 8	Specific exceptions before generic Exception
Ex 9	traceback.print_exc() for detailed error info
Ex 10-11	finally block — always executes (resource cleanup)
Ex 12	Complete try-except-else-finally structure
Ex 13	raise keyword for manual exception raising
Ex 14-15	Catching vs not catching raised exceptions
Ex 16-18	Custom exception class (InvalidAgeError)

# %%
Here's the complete list of all standard built-in exceptions in Python:

🏗️ Exception Hierarchy (Base Classes)
Exception	Description
BaseException	Root class for ALL exceptions
Exception	Base class for all non-exit exceptions
ArithmeticError	Base class for math-related errors
LookupError	Base class for key/index errors
OSError	Base class for OS-related errors
ValueError	Base class for value-related errors
BufferError	Buffer operation errors

🔢 Arithmetic / Math Errors
Exception	Description	Example
ZeroDivisionError	Division or modulo by zero	10 / 0
OverflowError	Result too large to represent	math.exp(1000)
FloatingPointError	Floating point operation failed	Rare, needs fpectl

📋 Index / Key / Lookup Errors
Exception	Description	Example
IndexError	List/tuple index out of range	[1,2,3][5]
KeyError	Dictionary key not found	{"a":1}["b"]

📝 Type / Value Errors
Exception	Description	Example
TypeError	Wrong data type used	"2" + 2
ValueError	Correct type but wrong value	int("abc")

📛 Name / Attribute Errors
Exception	Description	Example
NameError	Variable not defined	print(x) (x undefined)
AttributeError	Object has no such attribute	"hello".push("a")
UnboundLocalError	Local variable referenced before assignment	Using var before =

📂 File / OS Errors
Exception	Description	Example
FileNotFoundError	File doesn't exist	open("xyz.txt")
FileExistsError	File already exists	os.mkdir("existing_dir")
PermissionError	No permission to access	Writing to read-only file
IsADirectoryError	Expected file, got directory	open("/Users/")
NotADirectoryError	Expected directory, got file	os.listdir("file.txt")
TimeoutError	Operation timed out	Network timeout
ConnectionError	Base for connection errors	Network issues
ConnectionRefusedError	Connection refused by server	Server not running
ConnectionResetError	Connection reset by peer	Server dropped connection
ConnectionAbortedError	Connection aborted	Connection interrupted
BrokenPipeError	Writing to a closed pipe	Pipe closed early
InterruptedError	System call interrupted	Signal interrupt
BlockingIOError	Non-blocking I/O operation	Async I/O would block
ChildProcessError	Child process operation failed	Process errors
ProcessLookupError	Process doesn't exist	os.kill(bad_pid)

📥 Import Errors
Exception	Description	Example
ImportError	Module import failed	import nonexistent
ModuleNotFoundError	Module not found (subclass of ImportError)	import xyz123

💾 Memory Errors
Exception	Description	Example
MemoryError	Out of memory	Creating huge list
RecursionError	Max recursion depth exceeded	Infinite recursion

⚙️ Syntax / Indentation Errors
Exception	Description	Example
SyntaxError	Invalid Python syntax	if x = 5:
IndentationError	Wrong indentation	Missing/extra indent
TabError	Mixing tabs and spaces	Inconsistent indent

🔄 Iterator / Generator Errors
Exception	Description	Example
StopIteration	Iterator exhausted (no more items)	next() on empty iterator
StopAsyncIteration	Async iterator exhausted	__anext__() done
GeneratorExit	Generator closed	gen.close()

🔤 Encoding / Unicode Errors
Exception	Description	Example
UnicodeError	Base for Unicode errors	Unicode operations
UnicodeEncodeError	Cannot encode character	"ñ".encode("ascii")
UnicodeDecodeError	Cannot decode bytes	b'\xff'.decode("utf-8")
UnicodeTranslateError	Cannot translate character	Translation mapping error
⚠️ Warning Classes
Warning	Description
Warning	Base class for all warnings
DeprecationWarning	Feature will be removed in future
PendingDeprecationWarning	Feature may be deprecated soon
RuntimeWarning	Suspicious runtime behavior
SyntaxWarning	Suspicious syntax
UserWarning	User-defined warnings
FutureWarning	Behavior will change in future
ImportWarning	Import-related warnings
UnicodeWarning	Unicode-related warnings
ResourceWarning	Resource usage warnings
BytesWarning	Bytes-related warnings

🔧 Other Standard Errors
Exception	Description	Example
RuntimeError	General runtime error	Generic error
NotImplementedError	Abstract method not implemented	Subclass didn't override
AssertionError	assert statement failed	assert 1 == 2
EOFError	Unexpected end of input	input() on closed stdin
SystemError	Internal interpreter error	Python internal bug
ReferenceError	Weak reference to garbage collected object	Dead reference

🚪 System Exit Exceptions (Not caught by except Exception)
Exception	Description	Example
SystemExit	Raised by sys.exit()	sys.exit(0)
KeyboardInterrupt	User pressed Ctrl+C	Program interrupted

📊 Total: ~65+ built-in exceptions & warnings in Python 3
Tip: The most commonly encountered ones in everyday coding are: TypeError, ValueError, KeyError, IndexError, NameError, AttributeError, FileNotFoundError, ZeroDivisionError, ImportError, and SyntaxError.
