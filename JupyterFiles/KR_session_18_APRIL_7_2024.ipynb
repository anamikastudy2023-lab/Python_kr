# %%
ref notes on GUI  copy and  file in notes

# %%
Debugging and GUI making

# %%
Debugging : 

pdb module to be imported

c- contunue 
s- step 
n- next

break - break point_dtype
disable 1 - disable 1st break point 

clear1 - clears  1st break points
clear - clears  all break points

# %%
# pdb module to be imported, 

sample code to use for debugging

import pdb
pdb.set_trace()
print("start")
def add(num):
    result=0
    for x in range(num+1):
    result=result+x
    return result
var=int(input("Enter a number :"))
resp=add(var)
if resp>15:
    print("valid")
else:
    print("not valid")
print("end")

# %%
# GUI::

# %%
from tkinter import *
from tkinter import messagebox
def getvalue:
    u=el.get()
    p=e2.get()
    if not u or not p:
        messagebox.showerror(title="login fail", message="username/password cant be()'")
root=TkO
root. geometry("800x800" ) 
root.config(bg="#3e4259")
root. title("login page")

f1=Frane(root)

11=Label(f1, text="Username")
12=Label(f1, text="Password")

e1=Entry(f1)
e2=Entry(f1, show="*")

bt=Button(f1, text="login", command=getvalue)

l1.grid(row=1, column=1,padx=7,pady=7)
e1.grid(row=1, column=2,padx=7,pady=7)

l2.grid(row=2, column=1,padx=7,pady=7)
e2. grid(row=2, column=2,padx=7 ,pady=7)
bt.grid(row=3, columnspan=3)
f1. place(relx=0.5,rely=0.5,anchor=CENTER)
root.mainloop()

# %%
root=TkO
root.geometry("800x800")
root.config(bg="#3e4259")
root. title("login page")
f1=Frame(root)
onlinetraining.krnetworkcloud.org
anamikastudy2023@gmail.com
11=Label(f1, text="Username"9643509033
12=Label(f1, text="Password")
e1=Entry(f1)
e2=Entry(f1, show="*")
bt=Button (f1, text="login",
, command=getvalue)
11.grid(row=1, column=1,padx=7,pady=7)
el.grid(row=1, column=2,padx=7,pady=7)
12.grid(row=2, column=1,padx=7 ,pady=7)
e2. grid(row=2, column=2,padx=7 ,pady=7)
bt.grid(row=3, columnspan=3)
f1. place(relx=0.5,rely=0.5,anchor=CENTER)
root.mainloop

# %%
from tkinter import * 
from tkinter import messagebox 
def getvalue:
    u=e1.get()
    p=e2.getO
    if not u or not p:
        messagebox.showerror(title="login fail", message="username/password can't be en")
    if u=="root" and p=="redhat":
        root.destroy()
        master=Tk()
        master.geometry("800x800") 
        master.config(bg="#36522f")
        master.title("Home page")
        naster.mainloop()
    else:
        messagebox.showerror(title="login fail", message="username/password wrong")
root=Tk()
root.geometry("800x800")
root.config(bg="#3e4259")
root.title("login page")

f1=Frame(root)

# %%
# command to make an exe file - 
# change the current working directory
pyinstaller --onefile -w abc123.python 

# package file created 
# just double click to run it

# %%
KR_session_18_APRIL_7_2024.ipynb
