# %%
create aws

# %%
# AWS python automation :

# %%
create key-pair -refer program in chat 3

ways to create EC2 instance 

profile , security credentials - create key  from platform , 
                                - create key-pair from console   - aws configure is where we put the key-pair to connect to the instance
                                - create key-pair from python 

creating vpc, scripts of python to do everything on aws 
using s3 bucket to do crud operations on files

# %%
Lambda - function ,  Trigger in lambda
