# %%
Azure in automation with python

# %%
also ref chat(4).text for notes and notebook for more notes

# %%
import os 
import requests 
import calendar 
from azure.mgmt.costmanagement import CostManagementClient 
from azure.mgmt.billing import BillingManagementClient 
from azure.mgmt.costmanagement.models import QueryDefinition, QueryDataset, QueryTimePeri
from azure.identity import ClientSecretCredential

os.environ ['CLIENT_ID'] = '1df287d3-d342-4388-8a88-91333da983b9'
os.environ ['TENANT_ID' ]='90bbc866-1380-496b-b88f-6897a89c1d92' 
os.environ ['CLIENT_SECRET' ]='.8v8Q~HVtaPrrEQbUU5m5fW4DHoiSIG45qxrQaGi'
os.environ ["Azure_Subscription_ID"]='f47f64a3-2f7e-4054-b843-6c9cccba2088'

credentials = ClientSecretCredential(
        tenant_id=os.environ ["TENANT_ID"], 
        client_id=os. environ ["CLIENT_ID"], 
        client_secret=os.environ ["'CLIENT_SECRET"])

#startdate-datetime (datetime, today () • year, datetime. today () morth, 1)
#end date=datetime (datetime. today () -year, datetime.today () month, calendar .monthrang
#client = CostManagementClient (credentials)
client = BillingManagementClient(
credential=credentials, subscription_id="f47f64a3-2f7e-4054-b843-6c9cccba2088"'
)
'''

response = client.generate_cost_details_report.begin_create_operation(
scope="subscriptions/f47f64a3-2f7e-4054-b843-6c9cccba2088"'
parameters={ "metric": "ActualCost", "timePeriod" : {"end": "2024-04-26" , "start" : "2
print (response.blobs[0].blob_link)
resp=requests.get(response.blobs[0].blob_link)
'''

response = client.billing,accounts.list()
for item in response:
print(item)

# %%
import paramiko 
import getpass

ip='13.201.31.199' 
port=22
username='ec2-user' 
password=getpass.getpass() 

ssh=paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy) 
ssh.connect(ip,port,username,password)
stdin, stdout, stderr=ssh.exec_command('mkdir demo') 
outlines=stdout.readlines()
print(outlines)

# %%
import paramiko 
importgetpass I

ip='13.201.31.199' 
port=22
username='ec2-user' 
password=getpass.getpass()

ssh=paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh. connect(ip,port,username,password) 
stdin, stdout, stderr=ssh.exec_command('ls') 
outlines=stdout.readlines()
print(outlines)

# %%
import paramiko
import getpass
import time

ip='13.201.31.199' 
port=22
username='ec2-user' 
password=getpass.getpass()

ssh=paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy)
ssh.connect(ip,port,username,password)
stdin, stdout, stderr=ssh.exec_command('ls') 
time.sleep(4) 
outlines=stdout.readlines()
print(outlines)

# %%
demo11.py # -- save file as this 

import paramiko
import getpass
import time

ip='13.201.31.199'
port=22
username='ec2-user' 
password=getpass.getpass
ssh=paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh.connect(ip,port,username,password)
ftp_client=ssh.open_sftp()
ftp_client.put("/Users/admin/Documents/demo11.py","test.py")

# %%
# run->
python demo11.py
ssh ec2-user@13.201.31.199         #  here give your instance public ip
ls 
pwd

ssh -i "krawskey2.pem" ubuntu@ec2-43-204-218-24.ap-south-1.compute.amazonaws.com
